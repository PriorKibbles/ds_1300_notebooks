# %% [markdown]
# # Working with Data

# %% [markdown]
# >Using the data below, answer the following questions:
#
# >1) Which entities (top 5) had the largest population density in 2020?
# >2) Which entities have more water area than land area?
# >3) Which entities increased in population the most in the last 10 years?
# >4) What state bird accounts for the largest population as of 2020? Land area?
# >5) How many entities' largest city is their capital city?
# >6) Which city has the largest percent drop from their largest city to their 5th largest? 100*(1st largest - 5th largest)/(1st largest)

# %%
import pandas as pd

# %%
facts = pd.read_csv('../data/state_facts.tsv',delimiter="\t")
facts.head(5)
# Out:
#               State  Area_tot  Area_land  Area_water   Pop_2020  Pop_2010  \
# 0          Alabama     135767     131171        4597  5024279.0   4779736
# 1           Alaska    1723337    1477953      245384   733391.0    710231
# 2   American Samoa       1505        198        1307    49437.0     55519
# 3          Arizona     295234     294207        1026  7151502.0   6392017
# 4         Arkansas     137732     134771        2961  3011524.0   2915918
#
#   Rep_seats                        State_bird             State_flower  \
# 0         7  Yellowhammer (Northern flicker)                  Camellia
# 1         1                 Willow ptarmigan            Forget-me-not
# 2       1*                               None         Paogo (Ulafala)
# 3         9                      Cactus wren   Saguaro cactus blossom
# 4         4             Northern mockingbird            Apple blossom
#
#                       State_motto  ...        City_1 city_1_pop       City_2  \
# ...

# %%
facts['Population Density']=facts['Pop_2020']/facts['Area_tot']
facts.sort_values(by='Population Density',ascending=False)
#1 DC, New Jersey, Rhode Island, Massachusetts, Connecticut
# Out:
#                              State  Area_tot  Area_land  Area_water  \
# 9            District of Columbia        177        158          19
# 32                     New Jersey      22591      19047        3544
# 43                   Rhode Island       4001       2678        1324
# 23                  Massachusetts      27336      20202        7134
# 7                     Connecticut      14357      12542        1816
# 42                    Puerto Rico      13791       8868        4924
# 22                       Maryland      32131      25142        6990
# 8                        Delaware       6446       5047        1399
# 34                       New York     141297     122057       19240
# 10                        Florida     170312     138887       31424
# 41                   Pennsylvania     119280     115883        3397
# 38                           Ohio     116098     105829       10269
# 5                      California     423967     403466       20501
# ...

# %%
facts[(facts['Area_water']>facts['Area_land'])]
#2 American Samoa, Guam, Northern Mariana Islands, US Virgin Islands
# Out:
#                              State  Area_tot  Area_land  Area_water  Pop_2020  \
# 2                  American Samoa       1505        198        1307   49437.0
# 12                           Guam       1478        543         935     168.4
# 37       Northern Mariana Islands       5117        472        4644      51.0
# 48   United States Virgin Islands       1898        348        1550  106235.0
#
#     Pop_2010 Rep_seats           State_bird                State_flower  \
# 2      55519       1*                  None            Paogo (Ulafala)
# 12    159358       1*   Guam rail (ko'ko')   Bougainvillea spectabilis
# 37     53883       1*   Mariana fruit-dove                 Flores mayo
# 48    106405       1*      California gull                Yellow Elder
#
#                     State_motto  ... city_1_pop       City_2  city_2_pop  \
# 2        Samoa, Muamua Le Atua   ...       7945     Nu'uuli       3955.0
# ...

# %%
facts['Population Increase']=facts['Pop_2020']-facts['Pop_2010']
facts.sort_values(by='Population Increase',ascending=False)
#3 Texas, Florida, California, Georgia, Washington
# Out:
#                              State  Area_tot  Area_land  Area_water  \
# 47                          Texas     695662     676587       19075
# 10                        Florida     170312     138887       31424
# 5                      California     423967     403466       20501
# 11                        Georgia     153910     148959        4951
# 52                     Washington     184661     172119       12542
# 35                 North Carolina     139391     125920       13471
# 34                       New York     141297     122057       19240
# 3                         Arizona     295234     294207        1026
# 6                        Colorado     269601     268431        1170
# 51                       Virginia     110787     102279        8508
# 46                      Tennessee     109153     106798        2355
# 49                           Utah     219882     212818        7064
# 32                     New Jersey      22591      19047        3544
# ...

# %%
birds = facts[["Pop_2020","State_bird"]].groupby(by='State_bird').sum()
birds.sort_values(by='Pop_2020',ascending=False)
#4 Northern Mockingbird 
birds = facts[["Area_land","State_bird"]].groupby(by='State_bird').sum()
birds.sort_values(by='Area_land',ascending=False)
#4 Willow ptarmigan
# Out:
#                                          Area_land
# State_bird
# Willow ptarmigan                           1477953
# Western meadowlark                         1215009
# Northern mockingbird                       1178574
# Northern cardinal                           735138
# Mountain bluebird                           498377
# California quail                            403466
# Greater roadrunner                          314161
# Eastern bluebird                            300097
# American robin                              299245
# Cactus wren                                 294207
# Lark bunting                                268431
# Western meadowlark                          251470
# Hermit thrush                               212818
# Common loon                                 206232
# Ring-necked pheasant                        196350
# Scissor-tailed flycatcher                   177660
# Willow goldfinch (American goldfinch)       172119
# ...

# %%
facts[(facts['Capital_pop']>facts['city_1_pop'])]
#5 10
# Out:
#                              State  Area_tot  Area_land  Area_water  \
# 3                         Arizona     295234     294207        1026
# 6                        Colorado     269601     268431        1170
# 9            District of Columbia        177        158          19
# 11                        Georgia     153910     148959        4951
# 14                          Idaho     216443     214045        2398
# 16                        Indiana      94326      92789        1537
# 37       Northern Mariana Islands       5117        472        4644
# 38                           Ohio     116098     105829       10269
# 39                       Oklahoma     181037     177660        3377
# 42                    Puerto Rico      13791       8868        4924
# 43                   Rhode Island       4001       2678        1324
# 48   United States Virgin Islands       1898        348        1550
# 55                        Wyoming     253335     251470        1864
#
# ...

# %%
facts['Percent_Drop']=100*(facts['city_1_pop']-facts['city_5_pop'])/facts['city_1_pop']
facts[['State','City_1','city_1_pop','City_5','city_5_pop','Percent_Drop']].sort_values(by='Percent_Drop',ascending=False).head()
# 6
# Out:
#              State          City_1  city_1_pop      City_5  city_5_pop  \
# 34       New York   New York City      8879928   Syracuse     142749.0
# 1          Alaska       Anchorage       291538      Sitka       8647.0
# 15       Illinois         Chicago      2705994   Rockford     146526.0
# 41   Pennsylvania    Philadelphia      1587828    Reading      88495.0
# 19       Kentucky      Louisville       620578  Covington      40366.0
#
#     Percent_Drop
# 34     98.392453
# 1      97.034006
# 15     94.585132
# 41     94.426663
# 19     93.495419

# %% [markdown]
# >Using the "state_dates.tsv" data, answer the remaining questions. You will need to merge the two data sets together:
#
# >7) Of the states that joined the United States before 1790, what is the most common state flower?
# >8) Which has the larger population density, the most dense US Territory or the least dense state?
# >9) Make a graph that plots the populations of the largest city in each entity in the order in which they joined the US. Make the bars black
# >10) Make two additional graphs like the one above but one for land area (green bars) and one for water area (blue bars)

# %% [markdown]
# Hint: `pd.read_csv('../data/state_dates.tsv',delimiter="\t")`
#
# Hint: You likely want to convert the Date column to datetime. You might have to correct errors in the data as well.
#
# Hint: `states['Date']<pd.datetime(1790,1,1)`
#
# Hint: `pd.merge(****,****,left_on='USPS_code',right_on='Abbreviation',how='outer')`

# %%
# Sample code to help with the plots

#import matplotlib as plt
#%config InlineBackend.figure_format ='retina' #This makes your plot clearer


#plot = *your df by date*[[*column*,'Abbreviation']].plot(kind='bar',figsize=(10,4))
#plot.set_xticklabels(*your df by date*['Abbreviation']);

# %%
#7 Mountain Laurel
dates = pd.read_csv('../data/state_dates.tsv',delimiter="\t")
dates.head()
# Out:
#              Name               Date     Status Abbreviation
# 0        Alabama   December 14, 1819      State          AL
# 1         Alaska     January 3, 1959      State          AK
# 2  American Samoa     April 17, 1900  Territory           AS
# 3        Arizona   February 14, 1912      State          AZ
# 4       Arkansas       June 15, 1836      State          AR

# %%
len(facts)
# Out:
# 56

# %%
facts.columns
# Out:
# Index(['State', 'Area_tot', 'Area_land', 'Area_water', 'Pop_2020', 'Pop_2010',
#        'Rep_seats', 'State_bird', 'State_flower', 'State_motto', 'Motto_trans',
#        'USPS_code', 'GDP_2020', 'GDP_2019', 'Capital', 'Capital_pop', 'City_1',
#        'city_1_pop', 'City_2', 'city_2_pop', 'City_3', 'city_3_pop', 'City_4',
#        'city_4_pop', 'City_5', 'city_5_pop', 'Population Density',
#        'Population Increase', 'Percent_Drop'],
#       dtype='object')

# %%
dates.columns
# Out:
# Index(['Name', 'Date', 'Status', 'Abbreviation'], dtype='object')

# %%
states = pd.merge(facts,dates,left_on='USPS_code',right_on='Abbreviation',how='outer')

# %%
states = pd.merge(facts,dates,left_on='USPS_code',right_on='Abbreviation',how='outer')

# %%
states.head()
# Out:
#               State  Area_tot  Area_land  Area_water   Pop_2020  Pop_2010  \
# 0          Alabama     135767     131171        4597  5024279.0   4779736
# 1           Alaska    1723337    1477953      245384   733391.0    710231
# 2   American Samoa       1505        198        1307    49437.0     55519
# 3          Arizona     295234     294207        1026  7151502.0   6392017
# 4         Arkansas     137732     134771        2961  3011524.0   2915918
#
#   Rep_seats                        State_bird             State_flower  \
# 0         7  Yellowhammer (Northern flicker)                  Camellia
# 1         1                 Willow ptarmigan            Forget-me-not
# 2       1*                               None         Paogo (Ulafala)
# 3         9                      Cactus wren   Saguaro cactus blossom
# 4         4             Northern mockingbird            Apple blossom
#
#                       State_motto  ... city_4_pop       City_5  city_5_pop  \
# ...

# %%
states['Date']=pd.to_datetime(states['Date'])

# %%
states.head()
# Out:
#               State  Area_tot  Area_land  Area_water   Pop_2020  Pop_2010  \
# 0          Alabama     135767     131171        4597  5024279.0   4779736
# 1           Alaska    1723337    1477953      245384   733391.0    710231
# 2   American Samoa       1505        198        1307    49437.0     55519
# 3          Arizona     295234     294207        1026  7151502.0   6392017
# 4         Arkansas     137732     134771        2961  3011524.0   2915918
#
#   Rep_seats                        State_bird             State_flower  \
# 0         7  Yellowhammer (Northern flicker)                  Camellia
# 1         1                 Willow ptarmigan            Forget-me-not
# 2       1*                               None         Paogo (Ulafala)
# 3         9                      Cactus wren   Saguaro cactus blossom
# 4         4             Northern mockingbird            Apple blossom
#
#                       State_motto  ... city_4_pop       City_5  city_5_pop  \
# ...

# %%
states[states['Date']<pd.datetime(1790,1,1)]['State_flower'].value_counts()
# Out:
# <ipython-input-57-c8ba0baebf0c>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   states[states['Date']<pd.datetime(1790,1,1)]['State_flower'].value_counts()
# Mountain laurel      2
# Purple lilac         1
# Rose                 1
# Flowering dogwood    1
# Peach blossom        1
# Cherokee rose        1
# American dogwood     1
# Yellow jessamine     1
# Violet               1
# Mayflower            1
# Black-eyed susan     1
# Name: State_flower, dtype: int64

# %%
#8 Most dense US territory; Puerto Rico 
ter = states[states['Status']=='Territory']

# %%
sta = states[states['Status']=='State']

# %%
ter['PopDensity2020'] = ter['Pop_2020']/ter['Area_land']
ter = ter.sort_values(by = 'PopDensity2020', ascending = False)
ter[['State','PopDensity2020']].head(1)
# Out:
# <ipython-input-60-21aa668e0f6d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ter['PopDensity2020'] = ter['Pop_2020']/ter['Area_land']
#             State  PopDensity2020
# 42   Puerto Rico       370.531574

# %%
sta['PopDensity2020'] = sta['Pop_2020']/sta['Area_land']
sta = sta.sort_values(by = 'PopDensity2020', ascending = True)
sta[['State','PopDensity2020']].head(1)
# Out:
#       State  PopDensity2020
# 1   Alaska         0.496221

# %%
#9
statesbydate = states.sort_values(by='Date')
import matplotlib as plt
# %config InlineBackend.figure_format ='retina' #This makes your plot clearer
plot = statesbydate[['city_1_pop','Abbreviation']].plot(kind='bar',figsize=(10,4),color='red')
plot.set_xticklabels(statesbydate['Abbreviation']);

# %%
#10
plot = statesbydate[['Area_land','Abbreviation']].plot(kind='bar',figsize=(10,4),color='green')
plot.set_xticklabels(statesbydate['Abbreviation']);

plot = statesbydate[['Area_water','Abbreviation']].plot(kind='bar',figsize=(10,4),color='blue')
plot.set_xticklabels(statesbydate['Abbreviation']);
