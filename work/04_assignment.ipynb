# %% [markdown]
# # Data Visualization

# %% [markdown]
# Select a dataset we have used in class (or outside of class).
#
# Generate a plot that you feel visualizes the data is an interesting way. Your plot should have the following elements:
#
# >1) Title
# >2) Legend
# >3) Axes or other Labels
# >4) Color
# >5) 1 sentence description of what your plot shows
# >6) Brief description of why you chose to make the plot the way you did.
#
# You may use pandas, matplotlib, or seaborn.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../work/2010-2011.csv',delimiter=",")
df["Composite"] = (df["W"]/df["L"])*df["NRtg"]+df["MOV"]
df2011 = df.sort_values(by="Composite", ascending = False)
df2011.head(8)
# Out:
#    Rk                Team Conf Div   W   L   W/L%   MOV    ORtg    DRtg  NRtg  \
# 1   2       Chicago Bulls    E   C  62  20  0.756  7.32  109.30  101.07  8.23
# 0   1          Miami Heat    E  SE  58  24  0.707  7.46  112.62  104.35  8.27
# 3   4   San Antonio Spurs    W  SW  61  21  0.744  5.71  112.31  106.23  6.07
# 2   3  Los Angeles Lakers    W   P  57  25  0.695  6.11  111.61  105.00  6.61
# 5   6      Boston Celtics    E   A  56  26  0.683  5.37  107.36  101.46  5.90
# 4   5       Orlando Magic    E  SE  52  30  0.634  5.46  108.78  102.87  5.91
# 7   8    Dallas Mavericks    W  SW  57  25  0.695  4.23  110.24  105.76  4.49
# 6   7      Denver Nuggets    W  NW  50  32  0.610  4.76  112.84  108.03  4.82
#
#    MOV/A  ORtg/A  DRtg/A  NRtg/A  Champion  Composite
# 1   6.53  109.02  101.65    7.37         0  32.833000
# 0   6.76  112.43  104.94    7.49         0  27.445833
# 3   5.86  112.22  105.97    6.25         0  23.341905
# ...

# %%
plt.rcdefaults()
fig, ax = plt.subplots()

# Example data
subset = df2011[df2011['Composite']>12.29]
y_pos = np.arange(len(subset))

ax.barh(y_pos, subset['Composite'], align='center',color=['silver','silver','silver','silver','silver','silver','royalblue','silver'])
ax.set_yticks(y_pos)
ax.set_yticklabels(subset.Team.tolist())
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Composite Score')
ax.set_title('2010-2011 Top Contenders Based on Composite')
type = ['Runner-Up','Champion']
plt.legend(type)

plt.show()
plt.savefig('Graph.pdf')

# %%
#5 My plot shows the top title contenders for the 2010-2011 NBA season based off my of composite score criteria. 
#6 I chose to do a horizontal bar chart because it helps to show the composite score of the top teams compared to the rest of the contending means. I chose a horizontal bar chart instead of a regular bar chart because I think that this type of graph looks more visually appealing as the team names are on the y-axis. Furthermore, it shows the composite score compared to the scores of other teams. For the colors, I chose silver and blue because those are the colors of the champion of this year. The teams that did not win the championship are all the same color while the champion is a separate color.
